# %% [markdown]
# # MFA Tutorial on a Mixture-of-Experts (MoE) Model
#
# This notebook mirrors the original MFA tutorial through **visualization**, while also tracking **which MoE expert was activated per token**.

# %% [markdown]
# ## What this notebook covers
#
# 1. Load a Hugging Face MoE Causal LM
# 2. Extract hidden-state activations + router logits
# 3. Build MFA training loaders
# 4. Initialize and train MFA
# 5. Interpret components with top tokens
# 6. Visualize local subspaces
# 7. Track expert usage overall and per MFA component

# %%
from __future__ import annotations
import os
import random
from collections import Counter

import torch
import matplotlib.pyplot as plt
from tqdm import tqdm
from transformers import AutoTokenizer, AutoModelForCausalLM
from torch.utils.data import DataLoader, TensorDataset

from data_utils.concept_dataset import SupervisedConceptDataset
from initializations.projected_knn import ReservoirKMeans
from modeling.mfa import MFA
from modeling.train import train_nll
from analysis.subspace_interpretation import get_top_strings_per_concept
import analysis.subspace_visualization as sv

# %%
# Paths and runtime
data_path = "./data/supervised.json"
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# MoE model (change to any router-based MoE CausalLM available to you)
model_name = "jetmoe/JetMoE-8B"

# Reasonable extraction caps for interactive runs
batch_size_extract = 1
max_points = None
max_batches = 400
max_length = 96
activation_layer = 8
router_layer = 8
sample_seed = 0
shuffle_batches = True
val_frac = 0.1

num_centroids = 80
rank = 8
epochs = 2
lr = 1.5e-3
# Out:
# Using device: cuda

# %%
# Load tokenizer/model
dtype = torch.float16 if device == "cuda" else torch.float32
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

model_hf = AutoModelForCausalLM.from_pretrained(
    model_name,
    dtype=dtype,
    trust_remote_code=True,
)
model_hf = model_hf.to(device)

# JetMoE compatibility patch for some Transformers versions
if not hasattr(model_hf, "num_experts"):
    model_hf.num_experts = getattr(model_hf.config, "num_local_experts", None) or getattr(model_hf.config, "num_experts", None)
if not hasattr(model_hf, "num_experts_per_tok"):
    model_hf.num_experts_per_tok = getattr(model_hf.config, "num_experts_per_tok", None) or getattr(model_hf.config, "top_k", 2)

model_hf.eval()
print("Model loaded:", model_name)
# Out:
# Loading checkpoint shards: 100%|██████████| 4/4 [00:19<00:00,  4.83s/it]
# Model loaded: jetmoe/JetMoE-8B

# %%
dataset_obj = SupervisedConceptDataset(data_path)
print("Dataset loaded from", data_path)
# Out:
# Dataset loaded from ./data/supervised.json

# %%
# Probe router availability and shapes on one batch
probe_batch = dataset_obj.get_batches(batch_size=1)[0]
probe_enc = tokenizer(
    probe_batch["prompt"],
    return_tensors="pt",
    padding=True,
    truncation=True,
 )
probe_enc = {k: v.to(model_hf.device) for k, v in probe_enc.items()}

router_capture = {}

def capture_router_logits(module, module_input, module_output):
    if not isinstance(module_output, tuple) or len(module_output) < 2:
        raise RuntimeError("JetMoE MLP did not return router logits.")
    router_capture["router_logits"] = module_output[1].detach()

router_module = model_hf.model.layers[router_layer].mlp
hook_handle = router_module.register_forward_hook(capture_router_logits)
try:
    with torch.no_grad():
        probe_out = model_hf(
            **probe_enc,
            output_hidden_states=True,
            use_cache=False,
        )
finally:
    hook_handle.remove()

router_logits = router_capture.get("router_logits")
if router_logits is None:
    raise RuntimeError("This JetMoE layer did not expose router logits through its MLP forward pass.")

print("#hidden_states:", len(probe_out.hidden_states), "(includes embedding state)")
print("captured router tensor shape:", tuple(router_logits.shape))

del probe_out
# Out:
# #hidden_states: 25 (includes embedding state)
# captured router tensor shape: (37, 8)

# %%
# Inspect likely router/gate modules in the already-loaded model
router_like = [n for n, _m in model_hf.named_modules() if ("gate" in n.lower() or "router" in n.lower())]
print("Found router/gate-like modules:", len(router_like))
for n in router_like[:80]:
    print(n)
# Out:
# Found router/gate-like modules: 96
# model.layers.0.self_attention.experts.router
# model.layers.0.self_attention.experts.router.layer
# model.layers.0.mlp.router
# model.layers.0.mlp.router.layer
# model.layers.1.self_attention.experts.router
# model.layers.1.self_attention.experts.router.layer
# model.layers.1.mlp.router
# model.layers.1.mlp.router.layer
# model.layers.2.self_attention.experts.router
# model.layers.2.self_attention.experts.router.layer
# model.layers.2.mlp.router
# model.layers.2.mlp.router.layer
# model.layers.3.self_attention.experts.router
# model.layers.3.self_attention.experts.router.layer
# model.layers.3.mlp.router
# model.layers.3.mlp.router.layer
# model.layers.4.self_attention.experts.router
# model.layers.4.self_attention.experts.router.layer
# model.layers.4.mlp.router
# model.layers.4.mlp.router.layer
# model.layers.5.self_attention.experts.router
# model.layers.5.self_attention.experts.router.layer
# model.layers.5.mlp.router
# model.layers.5.mlp.router.layer
# model.layers.6.self_attention.experts.router
# model.layers.6.self_attention.experts.router.layer
# model.layers.6.mlp.router
# model.layers.6.mlp.router.layer
# model.layers.7.self_attention.experts.router
# model.layers.7.self_attention.experts.router.layer
# model.layers.7.mlp.router
# model.layers.7.mlp.router.layer
# model.layers.8.self_attention.experts.router
# model.layers.8.self_attention.experts.router.layer
# model.layers.8.mlp.router
# model.layers.8.mlp.router.layer
# model.layers.9.self_attention.experts.router
# model.layers.9.self_attention.experts.router.layer
# model.layers.9.mlp.router
# model.layers.9.mlp.router.layer
# model.layers.10.self_attention.experts.router
# model.layers.10.self_attention.experts.router.layer
# model.layers.10.mlp.router
# model.layers.10.mlp.router.layer
# model.layers.11.self_attention.experts.router
# model.layers.11.self_attention.experts.router.layer
# model.layers.11.mlp.router
# model.layers.11.mlp.router.layer
# model.layers.12.self_attention.experts.router
# model.layers.12.self_attention.experts.router.layer
# model.layers.12.mlp.router
# model.layers.12.mlp.router.layer
# model.layers.13.self_attention.experts.router
# model.layers.13.self_attention.experts.router.layer
# model.layers.13.mlp.router
# model.layers.13.mlp.router.layer
# model.layers.14.self_attention.experts.router
# model.layers.14.self_attention.experts.router.layer
# model.layers.14.mlp.router
# model.layers.14.mlp.router.layer
# model.layers.15.self_attention.experts.router
# model.layers.15.self_attention.experts.router.layer
# model.layers.15.mlp.router
# model.layers.15.mlp.router.layer
# model.layers.16.self_attention.experts.router
# model.layers.16.self_attention.experts.router.layer
# model.layers.16.mlp.router
# model.layers.16.mlp.router.layer
# model.layers.17.self_attention.experts.router
# model.layers.17.self_attention.experts.router.layer
# model.layers.17.mlp.router
# model.layers.17.mlp.router.layer
# model.layers.18.self_attention.experts.router
# model.layers.18.self_attention.experts.router.layer
# model.layers.18.mlp.router
# model.layers.18.mlp.router.layer
# model.layers.19.self_attention.experts.router
# model.layers.19.self_attention.experts.router.layer
# model.layers.19.mlp.router
# model.layers.19.mlp.router.layer

# %% [markdown]
# ## Extract activations and active experts
#
# For each non-padding token:
# - store activation at `activation_layer`
# - store top expert index from `router_layer`
# - store top expert probability

# %%
@torch.no_grad()
def extract_moe_activations_and_experts(
    dataset_obj,
    model,
    tokenizer,
    activation_layer: int,
    router_layer: int,
    batch_size: int = 4,
    max_points: int | None = None,
    max_batches: int | None = None,
    max_length: int = 64,
    shuffle_batches: bool = True,
    seed: int = 0,
 ):
    acts_all = []
    toks_all = []
    expert_all = []
    expert_p_all = []

    kept = 0
    bos_id = tokenizer.bos_token_id

    batches = list(dataset_obj.get_batches(batch_size=batch_size))
    if shuffle_batches:
        rng = random.Random(seed)
        rng.shuffle(batches)

    total_batches = len(batches) if max_batches is None else min(len(batches), max_batches)
    pbar = tqdm(enumerate(batches), total=total_batches, desc="Extracting activations", unit="batch")

    for batch_idx, batch in pbar:
        if max_batches is not None and batch_idx >= max_batches:
            break

        prompts = batch["prompt"]
        enc = tokenizer(
            prompts,
            return_tensors="pt",
            padding=True,
            truncation=True,
            max_length=max_length,
)
        enc = {k: v.to(model.device) for k, v in enc.items()}

        out = model(
            **enc,
            output_hidden_states=True,
            output_router_logits=True,
            use_cache=False,
        )

        hidden_states = out.hidden_states
        router_logits = out.router_logits
        if router_logits is None:
            raise RuntimeError("Router logits are None.")

        router_list = list(router_logits)
        if activation_layer >= len(hidden_states):
            raise ValueError(f"activation_layer={activation_layer} out of range [0, {len(hidden_states)-1}]")
        if router_layer >= len(router_list):
            raise ValueError(f"router_layer={router_layer} out of range [0, {len(router_list)-1}]")

        h = hidden_states[activation_layer]  # (B,S,D)
        r = router_list[router_layer]        # model-dependent shape

        if r.dim() == 4:
            r = r.mean(dim=-2)

        input_ids = enc["input_ids"]
        B, S = input_ids.shape

        # Normalize router logits to (B,S,E)
        if r.dim() == 3 and r.shape[0] == B and r.shape[1] == S:
            r3 = r
        elif r.dim() == 2 and r.shape[0] == B * S:
            r3 = r.view(B, S, -1)
        elif r.dim() == 2 and B == 1 and r.shape[0] == S:
            r3 = r.unsqueeze(0)
        else:
            raise ValueError(
                f"Unexpected router logits shape {tuple(r.shape)} for input shape {(B, S)}. "
                "Try a different router_layer after checking the probe output."
            )

        probs = torch.softmax(r3.float(), dim=-1)
        top_p, top_expert = probs.max(dim=-1)

        mask = enc["attention_mask"].bool()
        if bos_id is not None:
            mask = mask & (input_ids != bos_id)

        acts = h[mask].detach().cpu()
        toks = input_ids[mask].detach().cpu()
        exp = top_expert[mask].detach().cpu()
        exp_p = top_p[mask].detach().cpu()

        acts_all.append(acts)
        toks_all.append(toks)
        expert_all.append(exp)
        expert_p_all.append(exp_p)

        kept += acts.size(0)
        if (batch_idx + 1) % 25 == 0:
            pbar.set_postfix(tokens=kept)

        if max_points is not None and kept >= max_points:
            pbar.set_postfix(tokens=kept, stopped="max_points")
            break

        del out
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    X = torch.cat(acts_all, dim=0)
    T = torch.cat(toks_all, dim=0)
    E = torch.cat(expert_all, dim=0)
    P = torch.cat(expert_p_all, dim=0)

    if max_points is not None and X.size(0) > max_points:
        X = X[:max_points]
        T = T[:max_points]
        E = E[:max_points]
        P = P[:max_points]

    return X, T, E, P

# %%
# JetMoE extraction: capture real router logits from the layer MLP forward pass
@torch.no_grad()
def extract_moe_activations_and_experts(
    dataset_obj,
    model,
    tokenizer,
    activation_layer: int,
    router_layer: int,
    batch_size: int = 4,
    max_points: int | None = None,
    max_batches: int | None = None,
    max_length: int = 64,
    shuffle_batches: bool = True,
    seed: int = 0,
 ):
    acts_all = []
    toks_all = []
    expert_all = []
    expert_p_all = []

    kept = 0
    bos_id = tokenizer.bos_token_id

    batches = list(dataset_obj.get_batches(batch_size=batch_size))
    if shuffle_batches:
        rng = random.Random(seed)
        rng.shuffle(batches)

    total_batches = len(batches) if max_batches is None else min(len(batches), max_batches)
    pbar = tqdm(enumerate(batches), total=total_batches, desc="Extracting activations", unit="batch")

    for batch_idx, batch in pbar:
        if max_batches is not None and batch_idx >= max_batches:
            break

        prompts = batch["prompt"]
        enc = tokenizer(
            prompts,
            return_tensors="pt",
            padding=True,
            truncation=True,
            max_length=max_length,
        )
        enc = {k: v.to(model.device) for k, v in enc.items()}

        router_capture = {}

        def capture_router_logits(module, module_input, module_output):
            if not isinstance(module_output, tuple) or len(module_output) < 2:
                raise RuntimeError("JetMoE MLP did not return router logits.")
            router_capture["router_logits"] = module_output[1].detach()

        router_module = model.model.layers[router_layer].mlp
        hook_handle = router_module.register_forward_hook(capture_router_logits)
        try:
            out = model(
                **enc,
                output_hidden_states=True,
                use_cache=False,
            )
        finally:
            hook_handle.remove()

        hidden_states = out.hidden_states
        router_logits = router_capture.get("router_logits")
        if router_logits is None:
            raise RuntimeError("JetMoE layer did not expose router logits through its MLP forward pass.")

        if activation_layer >= len(hidden_states):
            raise ValueError(f"activation_layer={activation_layer} out of range [0, {len(hidden_states)-1}]")

        h = hidden_states[activation_layer]  # (B,S,D)

        input_ids = enc["input_ids"]
        B, S = input_ids.shape

        r = router_logits
        if r.dim() == 2 and r.shape[0] == B * S:
            r3 = r.view(B, S, -1)
        elif r.dim() == 3 and r.shape[0] == B and r.shape[1] == S:
            r3 = r
        else:
            raise ValueError(
                f"Unexpected router logits shape {tuple(r.shape)} for input shape {(B, S)}. "
                "Check the JetMoE router_layer setting."
            )

        probs = torch.softmax(r3.float(), dim=-1)
        top_p, top_expert = probs.max(dim=-1)

        mask = enc["attention_mask"].bool()
        if bos_id is not None:
            mask = mask & (input_ids != bos_id)

        acts = h[mask].detach().cpu()
        toks = input_ids[mask].detach().cpu()
        exp = top_expert[mask].detach().cpu()
        exp_p = top_p[mask].detach().cpu()

        acts_all.append(acts)
        toks_all.append(toks)
        expert_all.append(exp)
        expert_p_all.append(exp_p)

        kept += acts.size(0)
        if (batch_idx + 1) % 25 == 0:
            pbar.set_postfix(tokens=kept)

        if max_points is not None and kept >= max_points:
            pbar.set_postfix(tokens=kept, stopped="max_points")
            break

        del out
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    X = torch.cat(acts_all, dim=0)
    T = torch.cat(toks_all, dim=0)
    E = torch.cat(expert_all, dim=0)
    P = torch.cat(expert_p_all, dim=0)

    if max_points is not None and X.size(0) > max_points:
        X = X[:max_points]
        T = T[:max_points]
        E = E[:max_points]
        P = P[:max_points]

    return X, T, E, P

# %%
X_all, tokens, expert_ids, expert_probs = extract_moe_activations_and_experts(
    dataset_obj=dataset_obj,
    model=model_hf,
    tokenizer=tokenizer,
    activation_layer=activation_layer,
    router_layer=router_layer,
    batch_size=batch_size_extract,
    max_points=max_points,
    max_batches=max_batches,
    max_length=max_length,
    shuffle_batches=shuffle_batches,
    seed=sample_seed,
)

# Keep MFA numerics stable and consistent with model parameters
X_all = X_all.float()

print("Activation matrix:", tuple(X_all.shape), X_all.dtype)
print("Token ids:", tuple(tokens.shape))
print("Expert ids:", tuple(expert_ids.shape))
print("Expert probs:", tuple(expert_probs.shape))
# Out:
# Extracting activations: 100%|██████████| 400/400 [3:44:36<00:00, 33.69s/batch, tokens=15446]
# Activation matrix: (15446, 2048) torch.float32
# Token ids: (15446,)
# Expert ids: (15446,)
# Expert probs: (15446,)

# %%
# Train/validation split for a real held-out metric
n_total = len(X_all)
generator = torch.Generator().manual_seed(sample_seed)
perm = torch.randperm(n_total, generator=generator)
n_val = max(1, int(round(n_total * val_frac)))
val_idx = perm[:n_val]
train_idx = perm[n_val:]

X_train = X_all[train_idx]
tokens_train = tokens[train_idx]
expert_ids_train = expert_ids[train_idx]
expert_probs_train = expert_probs[train_idx]

X_val = X_all[val_idx]
tokens_val = tokens[val_idx]
expert_ids_val = expert_ids[val_idx]
expert_probs_val = expert_probs[val_idx]

print(f"Train split: {len(train_idx)} samples")
print(f"Val split: {len(val_idx)} samples")
print(f"Val fraction: {len(val_idx) / max(1, n_total):.3f}")
# Out:
# Train split: 13901 samples
# Val split: 1545 samples
# Val fraction: 0.100

# %%
# Main loaders
train_ds = TensorDataset(X_train, tokens_train)
val_ds = TensorDataset(X_val, tokens_val)
moe_ds = TensorDataset(X_train, tokens_train, expert_ids_train, expert_probs_train)
moe_ds_val = TensorDataset(X_val, tokens_val, expert_ids_val, expert_probs_val)

loader = DataLoader(train_ds, batch_size=64, shuffle=True, pin_memory=True)
val_loader = DataLoader(val_ds, batch_size=64, shuffle=False, pin_memory=True)
moe_loader = DataLoader(moe_ds, batch_size=128, shuffle=False, pin_memory=True)
moe_loader_val = DataLoader(moe_ds_val, batch_size=128, shuffle=False, pin_memory=True)

print("Train samples:", len(train_ds))
print("Val samples:", len(val_ds))
# Out:
# Train samples: 13901
# Val samples: 1545

# %%
# Overall expert usage summary
expert_counts = Counter(expert_ids.tolist())
print("Top 20 most-used experts:")
for e, c in expert_counts.most_common(20):
    print(f"Expert {e}: {c}")
# Out:
# Top 20 most-used experts:
# Expert 7: 3390
# Expert 0: 3025
# Expert 5: 2270
# Expert 3: 1614
# Expert 6: 1489
# Expert 4: 1254
# Expert 2: 1247
# Expert 1: 1157

# %% [markdown]
# ## Initialization

# %%
pool_size = max(1, round(len(loader.dataset) / 5))
knn = ReservoirKMeans(
    n_clusters=num_centroids,
    pool_size=pool_size,
    vocab_size=int(tokenizer.vocab_size),
    device=device,
    proj_dim=32,
)
centroids = knn.fit(loader)
print("Centroids:", tuple(centroids.shape))
# Out:
# Centroids: (80, 2048)

# %% [markdown]
# ## Training

# %%
mfa = MFA(centroids=centroids, rank=rank).to(device)
train_stats = train_nll(mfa, loader, val_loader=val_loader, epochs=epochs, lr=lr)
print("Best validation metric:", train_stats["best_metric"])
# Out:
# Epoch 01 | Step 000200 Train NLL=2186.617317: : 218it [00:09, 22.86it/s]
# [epoch 01] train NLL=2179.039827  val NLL=2089.618075 ** best **
# Epoch 02 | Step 000200 Train NLL=2007.745745: : 218it [00:08, 24.56it/s]
# [epoch 02] train NLL=2001.601545  val NLL=1935.740553 ** best **
# Restored best model from epoch 02 with metric=1935.740553
# Best validation metric: 1935.7405533380106

# %%
@torch.no_grad()
def eval_mfa_nll(model, data_loader):
    model.eval()
    total_nll = 0.0
    total_n = 0
    for batch in data_loader:
        x = batch[0].view(batch[0].size(0), -1).to(device)
        nll = model.nll(x)
        total_nll += float(nll.item()) * x.size(0)
        total_n += x.size(0)
    return total_nll / max(1, total_n)

train_nll_value = eval_mfa_nll(mfa, loader)
val_nll_value = eval_mfa_nll(mfa, val_loader)
print(f"Final train NLL: {train_nll_value:.6f}")
print(f"Final val NLL:   {val_nll_value:.6f}")
print(f"Generalization gap: {val_nll_value - train_nll_value:.6f}")

plt.figure(figsize=(6, 4))
plt.bar(["train", "val"], [train_nll_value, val_nll_value], color=["#4C78A8", "#F58518"])
plt.ylabel("NLL")
plt.title("MFA held-out metric on larger slice")
plt.tight_layout()
plt.show()
# Out:
# Final train NLL: 1905.171629
# Final val NLL:   1935.740553
# Generalization gap: 30.568925

# %% [markdown]
# ## Interpretation

# %%
def tok_to_str(tok_id):
    if isinstance(tok_id, torch.Tensor):
        tok_id = int(tok_id.item())
    return tokenizer.decode([tok_id])

# %%
results = get_top_strings_per_concept(mfa, loader, tok_to_str, score="likelihood")

N_RESULTS = 20
N_LINES = 8
TOP_POOL = 3000
SEED = 0
random.seed(SEED)

for i, (k, words) in enumerate(list(results.items())[:N_RESULTS]):
    pool = words[:min(TOP_POOL, len(words))]
    sample = random.sample(pool, k=min(N_LINES, len(pool)))
    print(f"\n[Component {k}]")
    print("-" * 40)
    for line in sample:
        print("  -", str(line).replace("\n", "\\n"))
# Out:
# [Component 0]
# ----------------------------------------
#   - .
#   - '
#   - .
#   -
#   - .
#   - '
#   - .
#   - .
#
# [Component 1]
# ----------------------------------------
#   - .
#   - .
#   - .
#   - '
#   - .
#   -
#   - .
#   - and
#
# [Component 2]
# ----------------------------------------
#   - but
#   - and
#   -
#   - .
#   - '
#   - .
#   - '
#   - the
#
# [Component 3]
# ----------------------------------------
#   - but
#   - making
#   - .
#   - .
#   - .
#   -
#   - .
#   - .
#
# [Component 4]
# ----------------------------------------
#   -
#   - .
#   - .
#   - 6
#   -
#   - .
#   - '
#   - '
#
# [Component 5]
# ----------------------------------------
#   - '
#   - '
#   - -
#   - '
#   - '
#   - -
#   -
#   - '
#
# [Component 6]
# ----------------------------------------
#   - the
#   - .
#   - .
#   - '
#   - '
#   - 2
#   - .
#   - .
#
# [Component 7]
# ----------------------------------------
#   - '
#   - .
#   - .
#   - .
#   - .
#   -
#   - .
#   - .
#
# [Component 8]
# ----------------------------------------
#   - .
#   - '
#   - 2
#   - '
#   - .
#   - '
#   - '
#   - '
#
# [Component 9]
# ----------------------------------------
#   - .
#   - .
#   - "
#   - .
#   - "
#   -
#   - '
#   - .
#
# [Component 10]
# ----------------------------------------
#   - .
#   - .
#   - .
#   - .
#   - '
#   - .
#   -
#   - .
#
# [Component 11]
# ----------------------------------------
#   - ,
#   - ,
#   - ,
#   - ,
#   - ,
#   - ,
#   - ,
#   - ,
#
# [Component 12]
# ----------------------------------------
#   - the
#   - the
#   - the
#   - the
#   - the
#   - the
#   - the
#   - the
#
# [Component 13]
# ----------------------------------------
#   - The
#   - The
#   - The
#   - The
#   - The
#   - The
#   - The
#   - The
#
# [Component 14]
# ----------------------------------------
#   - is
#   - .
#   - 2
#   - .
#   - in
#   - to
#   - .
#   - and
#
# [Component 15]
# ----------------------------------------
#   - .
#   - .
#   - but
#   - .
#   - .
#   - '
#   - .
#   - .
#
# [Component 16]
# ----------------------------------------
#   - .
#   - .
#   - .
#   - '
#   - .
#   - .
#   - .
#   - .
#
# [Component 17]
# ----------------------------------------
#   - '
#   - '
#   - '
#   - .
#   - '
#   -
#   -
#   - .
#
# [Component 18]
# ----------------------------------------
#   - '
#   - '
#   - '
#   - '
#   - '
#   - '
#   - 2
#   - '
#
# [Component 19]
# ----------------------------------------
#   - .
#   -
#   - .
#   - .
#   - .
#   - '
#   - 2
#   -

# %%
# Expert usage by hard MFA component assignment
num_experts = int(expert_ids.max().item()) + 1
num_components = mfa.K
comp_expert_counts = torch.zeros(num_components, num_experts, dtype=torch.long)

mfa.eval()
with torch.no_grad():
    for x, _tok, exp_id, _exp_p in moe_loader:
        x = x.to(device)
        alpha = mfa.responsibilities(x)
        comp = alpha.argmax(dim=1).cpu()
        for c, e in zip(comp.tolist(), exp_id.tolist()):
            comp_expert_counts[c, e] += 1

top_comp = torch.topk(comp_expert_counts.sum(dim=1), k=min(12, num_components)).indices.tolist()
print("Top experts per active component:")
for c in top_comp:
    top_e = torch.topk(comp_expert_counts[c], k=min(5, num_experts))
    pairs = [(int(e), int(v)) for e, v in zip(top_e.indices, top_e.values) if int(v) > 0]
    print(f"Component {c}: {pairs}")
# Out:
# Top experts per active component:
# Component 14: [(0, 387), (7, 157), (2, 75), (4, 69), (3, 49)]
# Component 45: [(1, 200), (7, 101), (4, 99), (2, 75), (0, 74)]
# Component 12: [(0, 319), (2, 118), (1, 43), (6, 34), (3, 30)]
# Component 20: [(7, 191), (0, 125), (1, 113), (5, 33), (4, 20)]
# Component 33: [(5, 269), (6, 206), (4, 21), (0, 7), (2, 4)]
# Component 23: [(7, 338), (5, 58), (3, 37), (0, 23), (6, 6)]
# Component 26: [(5, 314), (6, 59), (1, 3), (3, 1)]
# Component 79: [(6, 256), (4, 52), (1, 28), (5, 9), (0, 6)]
# Component 13: [(2, 197), (7, 128), (1, 11), (5, 2), (6, 1)]
# Component 1: [(2, 69), (1, 65), (3, 58), (0, 52), (6, 32)]
# Component 54: [(7, 98), (0, 81), (4, 40), (1, 28), (3, 28)]
# Component 65: [(0, 129), (3, 118), (6, 20), (1, 16), (7, 9)]

# %% [markdown]
# ## Visualizing

# %%
# Pick a dense component for visualization instead of a fixed sparse one
k_to_visualize = int(top_comp[0]) if len(top_comp) > 0 else 0
coords = sv.project_loader_to_subspace(
    mfa,
    loader,
    k=k_to_visualize,
    token_to_str=tok_to_str,
 )
print(f"Component {k_to_visualize}: {len(coords['tokens'])} points projected (hard assignment)")
print(f"  Hard assignments total: {int(comp_expert_counts[k_to_visualize].sum().item())}")
# Out:
# Component 14: 845 points projected (hard assignment)
#   Hard assignments total: 845

# %%
print(f"Coordinate statistics for component {k_to_visualize}:")
print(f"  Shape: {coords['coords'].shape}")
print(f"  U0 range: [{coords['coords'][:, 0].min():.3f}, {coords['coords'][:, 0].max():.3f}]")
print(f"  U1 range: [{coords['coords'][:, 1].min():.3f}, {coords['coords'][:, 1].max():.3f}]")
print(f"  U0 std: {coords['coords'][:, 0].std():.3f}")
print(f"  U1 std: {coords['coords'][:, 1].std():.3f}")

sv.plot_subspace_scatter(coords, dims=(0, 1), max_labels=150)
plt.show()
# Out:
# Coordinate statistics for component 14:
#   Shape: torch.Size([845, 8])
#   U0 range: [-11.752, 11.674]
#   U1 range: [-14.334, 3.968]
#   U0 std: 3.205
#   U1 std: 3.628

# %%
@torch.no_grad()
def count_hard_assignments(mfa, loader, num_components):
    """Count how many tokens have each component as argmax responsibility."""
    hard_counts = torch.zeros(num_components, dtype=torch.long)
    for x, _, _, _ in loader:
        x = x.to(mfa.mu.device)
        alpha = mfa.responsibilities(x)
        hard_assignments = alpha.argmax(dim=1).cpu()
        for c in hard_assignments:
            hard_counts[c] += 1
    return hard_counts

hard_counts = count_hard_assignments(mfa, moe_loader, mfa.K)
print("Hard assignment counts (argmax responsibility per token):")
for c in top_comp:
    print(f"  Component {c}: {int(hard_counts[c].item())} tokens")
# Out:
# Hard assignment counts (argmax responsibility per token):
#   Component 14: 845 tokens
#   Component 45: 652 tokens
#   Component 12: 562 tokens
#   Component 20: 520 tokens
#   Component 33: 510 tokens
#   Component 23: 470 tokens
#   Component 26: 377 tokens
#   Component 79: 356 tokens
#   Component 13: 339 tokens
#   Component 1: 320 tokens
#   Component 54: 320 tokens
#   Component 65: 302 tokens

# %%
# Expert-aware plot for points assigned to one component
@torch.no_grad()
def plot_component_with_experts(mfa, moe_loader, component_idx: int, dims=(0, 1), max_points=3000):
    U = mfa.W[component_idx]
    U = U / U.norm(dim=0, keepdim=True).clamp_min(1e-8)
    G = U.T @ U
    L = torch.linalg.cholesky(G + 1e-6 * torch.eye(G.shape[0], device=G.device, dtype=G.dtype))

    pts = []
    exps = []

    for x, _tok, exp_id, _exp_p in moe_loader:
        x_dev = x.to(mfa.mu.device)
        alpha = mfa.responsibilities(x_dev)
        mask = (alpha.argmax(dim=1).cpu() == component_idx)
        if mask.any():
            xk = x_dev[mask.to(x_dev.device)]
            XtU = xk @ U
            cT = torch.cholesky_solve(XtU.T, L, upper=False)
            C = cT.T.detach().cpu()
            pts.append(C)
            exps.append(exp_id[mask])

        if pts and sum(p.size(0) for p in pts) >= max_points:
            break

    if not pts:
        print("No points assigned to this component with hard assignments.")
        return

    C = torch.cat(pts, dim=0)[:max_points]
    E = torch.cat(exps, dim=0)[:max_points]

    i, j = dims
    x = C[:, i].numpy()
    y = C[:, j].numpy()
    e = E.numpy()

    plt.figure(figsize=(9, 6))
    sc = plt.scatter(x, y, c=e, s=8, alpha=0.7, cmap="tab20")
    plt.xlabel(f"u{i}")
    plt.ylabel(f"u{j}")
    plt.title(f"Component {component_idx}: subspace coords colored by expert id")
    cbar = plt.colorbar(sc)
    cbar.set_label("Expert ID")
    plt.grid(True, linewidth=0.5, alpha=0.35)
    plt.tight_layout()
    plt.show()

plot_component_with_experts(mfa, moe_loader, component_idx=k_to_visualize, dims=(0, 1))

# %% [markdown]
# ## Expert routing patterns: correlation with semantic fields

# %%
import json
from collections import defaultdict

# Load dataset to map back to semantic concepts
with open(data_path, 'r', encoding='utf-8') as f:
    dataset_raw = json.load(f)

# Dataset is a list of dicts: {sentence, concept}
# Build concept -> indices map
concept_map = defaultdict(list)
for idx, item in enumerate(dataset_raw):
    concept = item.get('concept', 'unknown')
    concept_map[concept].append(idx)

# Extract unique concepts (semantic fields)
concepts_list = sorted(set(item['concept'] for item in dataset_raw))
print(f"Found {len(concepts_list)} semantic fields: {concepts_list}")
print(f"Total samples in dataset: {len(dataset_raw)}")
print(f"Total extracted tokens: {len(tokens)}")
print()
print("Samples per semantic field:")
for concept in concepts_list:
    print(f"  {concept}: {len(concept_map[concept])}")
# Out:
# Found 250 semantic fields: ['CSS properties and values related to layout and alignment', 'CSS pseudo-classes related to hover and checked states', 'CSS styling properties and values', 'Java class and method structures', 'Java-related error messages and stack traces', 'URLs and links to online resources', 'URLs and references related to image sources and attributions', 'XML or markup language structure related to project build configurations', 'abbreviations or acronyms related to operational technology and investment structures', 'acronyms and abbreviations related to organizations and regulations', 'actions indicating movement or travel', 'affirmative responses or indicators of agreement', 'brand names and terms related to cruise lines', 'citations and references in scientific writing', 'citations in the text', 'code snippets and data parsing processes', 'colors and their descriptions in various contexts', 'concepts related to emotional struggles or desires', 'concepts related to sustainable travel and tourism', 'conversational phrases and expressions related to relationships and social interactions', 'countable numeric expressions and fractions', 'database-related syntax and parameters', 'dates and specific release information in the text', 'descriptive features of clothing and fashion items', 'discussions about ethical responsibilities and accountability in leadership', 'discussions about safety measures for vehicles and pedestrians', 'documentation or comments within code', 'elements and classes related to HTML and CSS formatting', 'elements related to absence or residual effects', 'elements related to aerial performances and dance', 'elements related to character development and personal struggles', 'elements related to conferences or academic gatherings', 'elements related to time and conditions in data queries', 'elements related to video game titles and brands', 'expressions highlighting the concept of completeness or sufficiency in offerings', 'expressions of strong emotions or personal experiences', 'expressions related to activation and its various forms in scientific contexts', 'expressions related to impact or effectiveness', 'formal terms and phrases related to legal or regulatory contexts', 'gerunds and present participles', 'information related to military actions and security incidents', 'instances of HTML file references', 'instances of significant historical references or events', 'instances of the phrase "pointed out."', 'instances of the pronoun "it" and its context', 'instances of the word "as" in various contexts', 'instances of the word "by."', 'instances of the word "clarify" and its variants', 'instances of the word "template" and its variations', 'instances of the word "this" and its variations in different contexts', 'instances of transition phrases indicating a sequence or progression', 'instructions or steps for downloading and installing software or games', 'issues related to academic fees and inflation', 'key scientific terms and references related to virology research', 'key terms related to governance and policy analysis', 'location names and associated administrative regions', 'mathematical terms and concepts related to sample complexity and estimation in statistics or analysis', 'measurements of distance or lengths', 'mentions of businesses, organizations, or community entities', 'mentions of editorial notes or references to editors', "mentions of individuals' names or prominent figures", 'mentions of software licenses or related legal terminology', 'mentions of subscription pricing', 'mentions of the "Star Wars" franchise', 'metrics related to business scale and store locations', 'names of individuals and their associated actions or characteristics', 'names of people and their titles or associations', 'names of people, particularly those in the music industry', 'names of specific individuals, particularly in sports contexts', 'negations and expressions of dissatisfaction', 'negative connota ...
# Total samples in dataset: 18000
# Total extracted tokens: 15446
#
# Samples per semantic field:
#   CSS properties and values related to layout and alignment: 72
#   CSS pseudo-classes related to hover and checked states: 72
#   CSS styling properties and values: 72
#   Java class and method structures: 72
#   Java-related error messages and stack traces: 72
#   URLs and links to online resources: 72
#   URLs and references related to image sources and attributions: 72
#   XML or markup language structure related to project build configurations: 72
#   abbreviations or acronyms related to operational technology and investment structures: 72
#   acronyms and abbreviations related to organizations and regulations: 72
#   actions indicating movement or travel: 72
#   affirmative responses or indicators of agreement: 72
#   brand names and terms related to cruise lines: 72
#   citations and references in scientific writing: 72
#   citations in the text: 72
#   code snippets and data parsing processes: 72
#   colors and their descriptions in various contexts: 72
#   concepts related to emotional struggles or desires: 72
#   concepts related to sustainable travel and tourism: 72
#   conversational phrases and expressions related to relationships and social interactions: 72
#   countable numeric expressions and fractions: 72
#   database-related syntax and parameters: 72
#   dates and specific release information in the text: 72
#   descriptive features of clothing and fashion items: 72
#   discussions about ethical responsibilities and accountability in leadership: 72
#   discussions about safety measures for vehicles and pedestrians: 72
#   documentation or comments within code: 72
#   elements and classes related to HTML and CSS formatting: 72
#   elements related to absence or residual effects: 72
#   elements related to aerial performances and dance: 72
#   elements related to character development and personal struggles: 72
#   elements related to conferences or academic gatherings: 72
#   elements related to time and conditions in data queries: 72
#   elements related to video game titles and brands: 72
#   expressions highlighting the concept of completeness or sufficiency in offerings: 72
#   expressions of strong emotions or personal experiences: 72
#   expressions related to activation and its various forms in scientific contexts: 72
#   expressions related to impact or effectiveness: 72
#   formal terms and phrases related to legal or regulatory contexts: 72
#   gerunds and present participles: 72
#   information related to military actions and security incidents: 72
#   instances of HTML file references: 72
#   instances of significant historical references or events: 72
#   instances of the phrase "pointed out.": 72
#   instances of the pronoun "it" and its context: 72
#   instances of the word "as" in various contexts: 72
#   instances of the word "by.": 72
#   instances of the word "clarify" and its variants: 72
#   instances of the word "template" and its variations: 72
#   instances of the word "this" and its variations in different contexts: 72
#   instances of transition phrases indicating a sequence or progression: 72
#   instructions or steps for downloading and installing software or games: 72
#   issues related to academic fees and inflation: 72
#   key scientific terms and references related to virology research: 72
#   key terms related to governance and policy analysis: 72
#   location names and associated administrative regions: 72
#   mathematical terms and concepts related to sample complexity and estimation in statistics or analysis: 72
#   measurements of distance or lengths: 72
#   mentions of businesses, organizations, or community entities: 72
#   mentions of editorial notes or references to editors: 72
#   mentions of individuals' names or prominent figures: 72
#   mentions of software licenses or related legal terminology: 72
#   mentions of subscription pricing: 72
#   mentions of the "Star Wars" franchise: 72
#   metrics related to business scale and store locations: 72
#   names of individuals and their associated actions or characteristics: 72
#   names of people and their titles or associations: 72
#   names of people, particularly those in the music industry: 72
#   names of specific individuals, particularly in sports contexts: 72
#   negations and expressions of dissatisfaction: 72
#   negative connotations related to giving up or leaving something behind: 72
#   negative expressions or conditions in a narrative context: 72
#   nouns and phrases related to products or items: 72
#   numerical data and statistics related to population or demographics: 72
#   numerical data related to manufacturing statistics: 72
#   numerical data, specifically measurements and dimensions: 72
#   numerical values related to quantities and measurements: 72
#   numerical values representing ages or significant counts: 72
#   occurrences of notable achievements or references to specific events and their outcomes: 72
#   occurrences of the name "Dina.": 72
#   occurrences of the name "Kozel.": 72
#   occurrences of the name "Louis.": 72
#   occurrences of the word "impl" and its variations, primarily relating to implementation in programming contexts: 72
#   occurrences of the word "text.": 72
#   occurrences of the word "there" and its variations: 72
#   periods at the end of sentences: 72
#   phrases about expectations and pressure in contexts such as performance or creativity: 72
#   phrases addressing the reader or discussing advice: 72
#   phrases and expressions related to freshness and renewal: 72
#   phrases and terms related to food, particularly comforting and nourishing concepts: 72
#   phrases expressing personal experiences and emotions: 72
#   phrases indicating expectation or obligation: 72
#   phrases indicating future actions or expectations: 72
#   phrases or words related to "movement" or "direction.": 72
#   phrases related to arts and humanities: 72
#   phrases related to avant-garde concepts and methodologies: 72
#   phrases related to business transactions and sales opportunities: 72
#   phrases related to governance and representation in Nigeria: 72
#   phrases related to personal struggles and challenges: 72
#   phrases related to research methodology and clinical trial design: 72
#   phrases related to sequences and patterns of recurring events or circumstances: 72
#   phrases related to superhero movies and their titles: 72
#   phrases related to tasks and actions: 72
#   phrases related to visual or detailed content presentation: 72
#   phrases that highlight relationships between different groups or categories of people: 72
#   phrases that indicate inequality or discrimination: 72
#   phrases that involve abundance or plenty of items: 72
#   positional references related to directionality: 72
#   positive attributes and specifications of mobile phones: 72
#   programming parameters and argument structures in code: 72
#   programming-related comments or documentation sections: 72
#   programming-related terms and concepts: 72
#   prominent characters and actors in movies: 72
#   prominent names or initials associated with specific actions or concepts: 72
#   punctuation and sentence structures: 72
#   punctuation marks and emotional expressions: 72
#   punctuation marks, particularly full stops: 72
#   recommendations related to coffee preparation and storage: 72
#   references and citations, particularly in academic contexts: 72
#   references to "pocket" in various contexts: 72
#   references to Capitol Hill and associated locations or events: 72
#   references to Vodafone products and services: 72
#   references to WordPress content and functionalities: 72
#   references to academic journals and publications: 72
#   references to academic or intellectual discourse: 72
#   references to academic programs and support services: 72
#   references to academic publications or journal details: 72
#   references to aerosols: 72
#   references to awards or recognitions: 72
#   references to biblical characters or passages: 72
#   references to biblical figures and texts: 72
#   references to businesses and community engagement: 72
#   references to certain settings or configurations within a cloud database context: 72
#   references to characters and their interpersonal dynamics: 72
#   references to classic movies and theatrical productions: 72
#   references to climate change and its impacts: 72
#   references to clothing and accessories: 72
#   references to cloud infrastructure and scalability: 72
#   references to competitive sports and athletic achievements: 72
#   references to cookies and their use on websites: 72
#   references to cooking and culinary experiences: 72
#   references to cultural festivals and their associated practices: 72
#   references to energy companies and power-related terms: 72
#   references to grass or grassy areas: 72
#   references to health services and pharmaceutical companies: 72
#   references to health-related conditions and medical procedures: 72
#   references to heart-related issues and conditions: 72
#   references to images and galleries related to home design and decor: 72
#   references to individuals or entities, particularly names: 72
#   references to infrastructure development and improvements: 72
#   references to innovative technology and wearable devices: 72
#   references to institutions and entities, particularly in an academic or corporate context: 72
#   references to job responsibilities and qualifications related to creative media management: 72
#   references to language, communication, and societal roles: 72
#   references to legal and regulatory terminology: 72
#   references to legal articles and legislative frameworks: 72
#   references to legal articles and provisions related to limited partnerships: 72
#   references to legal regulations and statutes: 72
#   references to nationalities or the pronouns associated with them: 72
#   references to news headlines or journalistic content: 72
#   references to personal achievements and roles in the creative arts: 72
#   references to physical posture and movement: 72
#   references to players and their actions in a sports context: 72
#   references to race and ethnicity, particularly focusing on the concept of whiteness and its implications: 72
#   references to relationships or connections between different concepts: 72
#   references to scientific theories and concepts related to energy and particle physics: 72
#   references to secondary or tertiary categories in various contexts: 72
#   references to societal structures or inequalities: 72
#   references to software features and updates: 72
#   references to software, applications, and related digital objects and processes: 72
#   references to soul music and its emotional depth: 72
#   references to specific projects or initiatives: 72
#   references to specific years in a timeline: 72
#   references to startup programs and their structure: 72
#   references to technical elements and processes related to music creation and performance: 72
#   references to technology and digital accessibility: 72
#   references to the Associated Press and its journalism: 72
#   references to the antibiotic "Trimethoprim" or related compounds and their variants: 72
#   references to the location "Ford" or related terms: 72
#   references to the use of cookies and data customization on websites: 72
#   references to the works and legacy of authors, particularly in literary discussions: 72
#   references to theft or crime-related activities: 72
#   references to types or descriptions of living spaces, particularly apartments: 72
#   references to various mayors and their actions: 72
#   references to violence and injuries: 72
#   reports of personal experiences expressed in the present tense: 72
#   requests for information and documentation needed for applying or submission processes: 72
#   sections that include inquiries or references to improvements and arrangements: 72
#   sections that indicate solutions or advice for technical problems: 72
#   special characters or symbols that represent important metrics or variables: 72
#   specific components related to food and cooking ingredients: 72
#   specific details related to government actions and proposals: 72
#   specific nouns and their associations in contexts related to health, sports, and societal issues: 72
#   specific technical terms or jargon related to science: 72
#   statements that assert or emphasize knowledge or clarity about topics: 72
#   structured data related to programming configurations: 72
#   technical programming terms and keywords related to coding structures: 72
#   technical specifications and features of products: 72
#   technical specifications and principles related to technology and engineering concepts: 72
#   technical terms and structure in programming or system design: 72
#   technical terms related to software development and package management: 72
#   temporal phrases indicating time or duration: 72
#   temporal references and significant events: 72
#   terms and phrases related to medical procedures and conditions affecting the body: 72
#   terms associated with bodily movements and physical conditions: 72
#   terms associated with calibration processes and equipment measurements: 72
#   terms associated with weather conditions: 72
#   terms related to advantages and disadvantages: 72
#   terms related to box office performance and earnings of movies: 72
#   terms related to coffee preparation and quality: 72
#   terms related to cryptocurrency: 72
#   terms related to cybersecurity measures and email delivery issues: 72
#   terms related to degrees of freedom in scientific contexts: 72
#   terms related to demographics and statistical analysis: 72
#   terms related to digital health and personal data management: 72
#   terms related to dyslexia and its awareness: 72
#   terms related to eye health and vision-related issues: 72
#   terms related to familial relationships and adoption: 72
#   terms related to homogeneity and heterogeneity in biological contexts: 72
#   terms related to immobilization or immobility: 72
#   terms related to insurance and financial services: 72
#   terms related to international relations and diplomatic contexts: 72
#   terms related to legal wrongdoing or unethical behavior: 72
#   terms related to overdiagnosis and its consequences in healthcare: 72
#   terms related to savings accounts and financial management: 72
#   terms related to sports plays and actions: 72
#   terms related to struggle and activism: 72
#   terms related to support and endorsement: 72
#   terms related to various career paths and professional experiences: 72
#   terms related to various forms of error, inconsistency, and inadequacy: 72
#   terms related to window and style properties in web development: 72
#   the concept of prolongation or extended durations in various contexts: 72
#   the presence of numerical indicators or rankings within the text: 72
#   the word "following" and its variations in context: 72
#   themes related to literature and its critical analysis: 72
#   titles and names of music albums or songs: 72
#   titles and names of television shows and movies: 72
#   topics related to dietary components and health implications: 72
#   topics related to medical procedures and their effectiveness: 72
#   types of baked goods and desserts: 72
#   updates and announcements related to events and reviews: 72
#   variable definitions and data structure elements: 72
#   variations of the word "ach" related to pain or difficulty: 72
#   variations of the word "rediscover.": 72
#   various forms of the verb "adopt.": 72
#   words and phrases related to Islamic concepts and terminology: 72
#   words associated with excessive indulgence or moral decline: 72
#   words related to confections and sweets: 72
#   words related to insertion and adding components in various contexts: 72
#   words related to strategy and planning: 72

# %%
@torch.no_grad()
def analyze_expert_routing_by_semantic_proximity():
    """
    Analyze if tokens with similar semantic content activate similar experts.
    Strategy: group tokens by their MFA component (semantic field proxy), 
    then compute expert concentration per component.
    """
    component_expert_dist = defaultdict(lambda: defaultdict(int))
    component_token_count = defaultdict(int)
    
    for x, toks, exp_ids in zip(X_all, tokens, expert_ids):
        x = x.to(device).unsqueeze(0)
        alpha = mfa.responsibilities(x)
        component = alpha.argmax(dim=1).item()
        
        expert = int(exp_ids.item())
        component_expert_dist[component][expert] += 1
        component_token_count[component] += 1
    
    # Compute expert entropy per component (high = diverse, low = concentrated)
    expert_entropy_per_comp = {}
    for comp in component_expert_dist:
        expert_probs = torch.tensor([
            component_expert_dist[comp][e] / component_token_count[comp] 
            for e in range(num_experts)
        ])
        entropy = -torch.sum(expert_probs[expert_probs > 0] * torch.log(expert_probs[expert_probs > 0])).item()
        expert_entropy_per_comp[comp] = entropy
    
    return component_expert_dist, expert_entropy_per_comp, component_token_count

print("Computing expert routing patterns by MFA component...")
comp_exp_dist, comp_exp_entropy, comp_tok_count = analyze_expert_routing_by_semantic_proximity()

print("\nExpert entropy per MFA component (proxy for semantic field):")
print("(Lower entropy = more specialized expert routing)")
for comp in sorted(comp_exp_entropy.keys()):
    print(f"  Component {comp}: entropy={comp_exp_entropy[comp]:.3f}, tokens={comp_tok_count[comp]}")
# Out:
# Computing expert routing patterns by MFA component...
#
# Expert entropy per MFA component (proxy for semantic field):
# (Lower entropy = more specialized expert routing)
#   Component 0: entropy=1.595, tokens=192
#   Component 1: entropy=1.899, tokens=354
#   Component 2: entropy=1.871, tokens=337
#   Component 3: entropy=0.850, tokens=334
#   Component 4: entropy=1.888, tokens=187
#   Component 5: entropy=1.544, tokens=138
#   Component 6: entropy=1.265, tokens=125
#   Component 7: entropy=1.352, tokens=97
#   Component 8: entropy=1.635, tokens=87
#   Component 9: entropy=1.586, tokens=293
#   Component 10: entropy=1.561, tokens=31
#   Component 11: entropy=1.347, tokens=198
#   Component 12: entropy=1.295, tokens=629
#   Component 13: entropy=0.831, tokens=380
#   Component 14: entropy=1.657, tokens=934
#   Component 15: entropy=1.613, tokens=126
#   Component 16: entropy=1.467, tokens=128
#   Component 17: entropy=1.414, tokens=146
#   Component 18: entropy=1.766, tokens=243
#   Component 19: entropy=0.095, tokens=52
#   Component 20: entropy=1.633, tokens=581
#   Component 21: entropy=1.485, tokens=64
#   Component 22: entropy=0.631, tokens=40
#   Component 23: entropy=0.993, tokens=520
#   Component 24: entropy=-0.000, tokens=1
#   Component 25: entropy=1.233, tokens=39
#   Component 26: entropy=0.513, tokens=414
#   Component 27: entropy=1.797, tokens=121
#   Component 28: entropy=0.682, tokens=125
#   Component 29: entropy=1.611, tokens=90
#   Component 30: entropy=1.678, tokens=65
#   Component 31: entropy=1.334, tokens=118
#   Component 32: entropy=1.196, tokens=191
#   Component 33: entropy=0.970, tokens=581
#   Component 34: entropy=1.150, tokens=133
#   Component 35: entropy=1.430, tokens=190
#   Component 36: entropy=1.490, tokens=131
#   Component 37: entropy=1.124, tokens=40
#   Component 38: entropy=1.686, tokens=187
#   Component 39: entropy=1.418, tokens=68
#   Component 40: entropy=1.667, tokens=52
#   Component 41: entropy=0.351, tokens=209
#   Component 42: entropy=1.474, tokens=89
#   Component 43: entropy=0.825, tokens=207
#   Component 44: entropy=1.679, tokens=150
#   Component 45: entropy=1.903, tokens=714
#   Component 46: entropy=-0.000, tokens=1
#   Component 47: entropy=0.483, tokens=224
#   Component 48: entropy=-0.000, tokens=1
#   Component 49: entropy=1.199, tokens=211
#   Component 50: entropy=1.459, tokens=142
#   Component 51: entropy=1.331, tokens=164
#   Component 52: entropy=1.543, tokens=297
#   Component 53: entropy=1.362, tokens=309
#   Component 54: entropy=1.798, tokens=360
#   Component 55: entropy=1.732, tokens=175
#   Component 56: entropy=1.238, tokens=314
#   Component 57: entropy=0.693, tokens=2
#   Component 58: entropy=1.302, tokens=186
#   Component 59: entropy=0.865, tokens=16
#   Component 60: entropy=1.390, tokens=53
#   Component 61: entropy=0.693, tokens=2
#   Component 62: entropy=1.686, tokens=76
#   Component 63: entropy=1.760, tokens=90
#   Component 64: entropy=1.481, tokens=158
#   Component 65: entropy=1.304, tokens=326
#   Component 66: entropy=1.360, tokens=139
#   Component 67: entropy=1.072, tokens=13
#   Component 68: entropy=1.524, tokens=260
#   Component 69: entropy=1.512, tokens=129
#   Component 70: entropy=0.637, tokens=3
#   Component 71: entropy=1.852, tokens=238
#   Component 72: entropy=1.584, tokens=69
#   Component 73: entropy=1.640, tokens=289
#   Component 74: entropy=1.812, tokens=25
#   Component 75: entropy=0.712, tokens=229
#   Component 76: entropy=0.404, tokens=170
#   Component 77: entropy=1.353, tokens=163
#   Component 78: entropy=1.032, tokens=89
#   Component 79: entropy=0.924, tokens=392

# %%
def compute_expert_component_correlation():
    """
    Measure how strongly experts correlate with specific MFA components.
    High correlation = expert specializes in particular semantic fields.
    """
    # Create contingency table: experts x components
    contingency = torch.zeros(num_experts, num_components, dtype=torch.long)
    
    for x, _, exp_id in zip(X_all, tokens, expert_ids):
        x = x.to(device).unsqueeze(0)
        alpha = mfa.responsibilities(x)
        comp = alpha.argmax(dim=1).item()
        exp = int(exp_id.item())
        contingency[exp, comp] += 1
    
    # For each expert, compute "specialization" as KL divergence from uniform
    specialist_scores = {}
    uniform_dist = torch.ones(num_components) / num_components
    
    for exp in range(num_experts):
        exp_dist = contingency[exp].float()
        if exp_dist.sum() > 0:
            exp_dist = exp_dist / exp_dist.sum()
            # KL divergence: high = specialized, low = generalist
            kl_div = torch.sum(exp_dist * (torch.log(exp_dist + 1e-10) - torch.log(uniform_dist + 1e-10))).item()
            specialist_scores[exp] = kl_div
        else:
            specialist_scores[exp] = 0.0
    
    return contingency, specialist_scores

contingency, specialist_scores = compute_expert_component_correlation()

print("\nTop 15 most specialized experts (high KL-divergence from uniform):")
sorted_experts = sorted(specialist_scores.items(), key=lambda x: x[1], reverse=True)
for exp, score in sorted_experts[:15]:
    top_comps = torch.topk(contingency[exp], k=min(3, num_components)).indices.tolist()
    top_counts = torch.topk(contingency[exp], k=min(3, num_components)).values.tolist()
    print(f"  Expert {exp}: specialization={score:.3f}, top_components={list(zip(top_comps, top_counts))}")

print("\nTop 15 most generalist experts (low KL-divergence):")
for exp, score in sorted_experts[-15:]:
    print(f"  Expert {exp}: specialization={score:.3f}")
# Out:
# Top 15 most specialized experts (high KL-divergence from uniform):
#   Expert 1: specialization=1.254, top_components=[(45, 213), (20, 133), (11, 90)]
#   Expert 6: specialization=1.209, top_components=[(79, 286), (33, 236), (9, 100)]
#   Expert 0: specialization=1.197, top_components=[(14, 426), (12, 362), (3, 257)]
#   Expert 2: specialization=1.181, top_components=[(13, 219), (12, 128), (45, 87)]
#   Expert 5: specialization=0.950, top_components=[(26, 340), (33, 304), (73, 116)]
#   Expert 4: specialization=0.863, top_components=[(45, 113), (9, 103), (28, 82)]
#   Expert 7: specialization=0.809, top_components=[(23, 373), (56, 206), (20, 204)]
#   Expert 3: specialization=0.677, top_components=[(65, 128), (68, 102), (2, 83)]
#
# Top 15 most generalist experts (low KL-divergence):
#   Expert 1: specialization=1.254
#   Expert 6: specialization=1.209
#   Expert 0: specialization=1.197
#   Expert 2: specialization=1.181
#   Expert 5: specialization=0.950
#   Expert 4: specialization=0.863
#   Expert 7: specialization=0.809
#   Expert 3: specialization=0.677

# %%
def analyze_semantic_expert_alignment():
    """
    Check if tokens in the same MFA component tend to activate the same experts.
    If yes, expert routing correlates with semantic clustering.
    """
    component_tokens = defaultdict(list)
    component_experts = defaultdict(list)
    
    for x, tok, exp in zip(X_all, tokens, expert_ids):
        x = x.to(device).unsqueeze(0)
        alpha = mfa.responsibilities(x)
        comp = alpha.argmax(dim=1).item()
        component_tokens[comp].append(tokenizer.decode([int(tok.item())]))
        component_experts[comp].append(int(exp.item()))
    
    # For each component, compute expert consistency
    expert_consistency = {}
    for comp in component_experts:
        experts = component_experts[comp]
        if len(experts) > 0:
            expert_counter = Counter(experts)
            # Consistency = max_expert_count / total_count (how often top expert activates)
            consistency = max(expert_counter.values()) / len(experts)
            expert_consistency[comp] = (consistency, expert_counter.most_common(1)[0])
    
    # Correlate component semantic homogeneity with expert consistency
    print("\nSemantic-Expert Alignment Analysis:")
    print("(Component semantic cohesion vs. expert routing consistency)")
    print()
    
    for comp in sorted(expert_consistency.keys())[:12]:
        consistency, (top_exp, top_count) = expert_consistency[comp]
        sample_tokens = component_tokens[comp][:5]
        num_unique_experts = len(set(component_experts[comp]))
        
        print(f"Component {comp}:")
        print(f"  Tokens: {len(component_tokens[comp])}")
        print(f"  Unique experts: {num_unique_experts}")
        print(f"  Expert consistency: {consistency:.3f} (top expert #{top_exp} activates {top_count}/{len(component_experts[comp])} times)")
        print(f"  Sample tokens: {sample_tokens[:3]}")
        print()
    
    return component_tokens, component_experts, expert_consistency

component_tokens, component_experts, expert_consistency = analyze_semantic_expert_alignment()
# Out:
# Semantic-Expert Alignment Analysis:
# (Component semantic cohesion vs. expert routing consistency)
#
# Component 0:
#   Tokens: 192
#   Unique experts: 7
#   Expert consistency: 0.344 (top expert #5 activates 66/192 times)
#   Sample tokens: ['leaves', 'opsis', 'plant']
#
# Component 1:
#   Tokens: 354
#   Unique experts: 8
#   Expert consistency: 0.203 (top expert #2 activates 72/354 times)
#   Sample tokens: ['I', 'I', 'I']
#
# Component 2:
#   Tokens: 337
#   Unique experts: 8
#   Expert consistency: 0.246 (top expert #3 activates 83/337 times)
#   Sample tokens: ['especially', 'totally', 'finally']
#
# Component 3:
#   Tokens: 334
#   Unique experts: 7
#   Expert consistency: 0.769 (top expert #0 activates 257/334 times)
#   Sample tokens: ['indicating', 'learning', 'looking']
#
# Component 4:
#   Tokens: 187
#   Unique experts: 8
#   Expert consistency: 0.267 (top expert #2 activates 50/187 times)
#   Sample tokens: ['one', 'x', '7']
#
# Component 5:
#   Tokens: 138
#   Unique experts: 8
#   Expert consistency: 0.377 (top expert #4 activates 52/138 times)
#   Sample tokens: ['-', '-', '-']
#
# Component 6:
#   Tokens: 125
#   Unique experts: 7
#   Expert consistency: 0.424 (top expert #3 activates 53/125 times)
#   Sample tokens: ['party', 'ro', 'ot']
#
# Component 7:
#   Tokens: 97
#   Unique experts: 8
#   Expert consistency: 0.526 (top expert #5 activates 51/97 times)
#   Sample tokens: ['gene', 'double', 'poison']
#
# Component 8:
#   Tokens: 87
#   Unique experts: 8
#   Expert consistency: 0.368 (top expert #7 activates 32/87 times)
#   Sample tokens: ['hack', 'ors', 'think']
#
# Component 9:
#   Tokens: 293
#   Unique experts: 8
#   Expert consistency: 0.352 (top expert #4 activates 103/293 times)
#   Sample tokens: ['`', '`', '`']
#
# Component 10:
#   Tokens: 31
#   Unique experts: 6
#   Expert consistency: 0.387 (top expert #7 activates 12/31 times)
#   Sample tokens: ['m', 'wood', 'fourth']
#
# Component 11:
#   Tokens: 198
#   Unique experts: 7
#   Expert consistency: 0.455 (top expert #1 activates 90/198 times)
#   Sample tokens: [',', ',', ',']

# %%
# Visualize the strongest expert-component associations as a heatmap
import numpy as np

# Pick the most specialized experts and the most active components
specialized_experts = [exp for exp, score in sorted_experts[:15]]
active_components = [comp for comp, _ in sorted(
    ((int(c), int(comp_expert_counts[c].sum().item())) for c in range(num_components)),
    key=lambda x: x[1],
    reverse=True,
)[:12]]

heatmap = contingency[specialized_experts][:, active_components].float()
row_sums = heatmap.sum(dim=1, keepdim=True).clamp_min(1.0)
heatmap = heatmap / row_sums

plt.figure(figsize=(12, 8))
plt.imshow(heatmap.numpy(), aspect="auto", cmap="magma")
plt.colorbar(label="Fraction of expert's activations in component")
plt.xticks(range(len(active_components)), [str(c) for c in active_components], rotation=45)
plt.yticks(range(len(specialized_experts)), [str(e) for e in specialized_experts])
plt.xlabel("MFA component")
plt.ylabel("Expert id")
plt.title("Expert-to-component specialization heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Soft routing bias

# %%
# Soft routing bias: smooth each component's expert distribution and compare to hard routing
smoothing = 1.0
component_expert_prior = (comp_expert_counts.float() + smoothing)
component_expert_prior = component_expert_prior / component_expert_prior.sum(dim=1, keepdim=True).clamp_min(1e-8)

# Hard expert usage from the current routing
hard_expert_usage = torch.bincount(expert_ids, minlength=num_experts).float()
hard_expert_usage = hard_expert_usage / hard_expert_usage.sum().clamp_min(1e-8)

# Soft expert usage: each token contributes its component-conditioned prior instead of one-hot expert id
soft_expert_usage = torch.zeros(num_experts, dtype=torch.float32)
for x, exp_id in zip(X_all, expert_ids):
    x = x.to(device).unsqueeze(0)
    alpha = mfa.responsibilities(x)
    comp = int(alpha.argmax(dim=1).item())
    soft_expert_usage += component_expert_prior[comp].cpu()
soft_expert_usage = soft_expert_usage / soft_expert_usage.sum().clamp_min(1e-8)

# Compare the most-used experts under hard vs soft routing
hard_top = torch.topk(hard_expert_usage, k=min(12, num_experts))
soft_top = torch.topk(soft_expert_usage, k=min(12, num_experts))

print("Hard routing top experts:")
for e, v in zip(hard_top.indices.tolist(), hard_top.values.tolist()):
    print(f"  Expert {e}: {v:.4f}")

print("\nSoft routing top experts:")
for e, v in zip(soft_top.indices.tolist(), soft_top.values.tolist()):
    print(f"  Expert {e}: {v:.4f}")

# Side-by-side chart for the top experts under either routing scheme
chart_experts = sorted(set(hard_top.indices.tolist()) | set(soft_top.indices.tolist()))
chart_experts = chart_experts[:12]
x = np.arange(len(chart_experts))
width = 0.38

plt.figure(figsize=(12, 5))
plt.bar(x - width / 2, hard_expert_usage[chart_experts].numpy(), width=width, label="Hard routing", alpha=0.85)
plt.bar(x + width / 2, soft_expert_usage[chart_experts].numpy(), width=width, label="Soft routing", alpha=0.85)
plt.xticks(x, [str(e) for e in chart_experts])
plt.xlabel("Expert id")
plt.ylabel("Normalized usage")
plt.title("Hard vs soft expert usage after component-conditioned smoothing")
plt.legend()
plt.tight_layout()
plt.show()

# Also show the smoothed component-expert prior as a heatmap
plt.figure(figsize=(12, 8))
plt.imshow(component_expert_prior.numpy(), aspect="auto", cmap="viridis")
plt.colorbar(label="Soft expert prior within component")
plt.xticks(range(num_experts), [str(e) for e in range(num_experts)], rotation=90)
plt.yticks(range(num_components), [str(c) for c in range(num_components)])
plt.xlabel("Expert id")
plt.ylabel("MFA component")
plt.title("Component-conditioned soft routing prior")
plt.tight_layout()
plt.show()
# Out:
# Hard routing top experts:
#   Expert 7: 0.2195
#   Expert 0: 0.1958
#   Expert 5: 0.1470
#   Expert 3: 0.1045
#   Expert 6: 0.0964
#   Expert 4: 0.0812
#   Expert 2: 0.0807
#   Expert 1: 0.0749
#
# Soft routing top experts:
#   Expert 7: 0.2157
#   Expert 0: 0.1942
#   Expert 5: 0.1450
#   Expert 3: 0.1038
#   Expert 6: 0.0984
#   Expert 2: 0.0830
#   Expert 4: 0.0818
#   Expert 1: 0.0780

# %%
# Evaluate routing change on held-out split: global prior vs component-conditioned soft prior
@torch.no_grad()
def evaluate_routing_quality(mfa, X_val, expert_ids_val, comp_expert_counts, expert_ids_train, device):
    num_components, num_experts = comp_expert_counts.shape

    # Baseline: global expert prior from train split
    global_counts = torch.bincount(expert_ids_train, minlength=num_experts).float()
    global_prior = (global_counts + 1.0) / (global_counts.sum() + num_experts)

    # Soft routing prior: P(expert | component) with Laplace smoothing
    comp_prior = (comp_expert_counts.float() + 1.0)
    comp_prior = comp_prior / comp_prior.sum(dim=1, keepdim=True).clamp_min(1e-8)

    # Assign validation points to components with trained MFA
    x_dev = X_val.to(device)
    alpha = mfa.responsibilities(x_dev)
    comp_val = alpha.argmax(dim=1).cpu()

    true_exp = expert_ids_val.cpu().long()

    # Log loss over true observed expert ids
    eps = 1e-9
    prob_global = global_prior[true_exp]
    prob_soft = comp_prior[comp_val, true_exp]

    nll_global = float((-torch.log(prob_global + eps)).mean().item())
    nll_soft = float((-torch.log(prob_soft + eps)).mean().item())

    # Top-1 / Top-3 agreement with observed expert ids
    pred_global_top1 = torch.argmax(global_prior).repeat(true_exp.numel())
    pred_soft_top1 = torch.argmax(comp_prior[comp_val], dim=1)

    top1_global = float((pred_global_top1 == true_exp).float().mean().item())
    top1_soft = float((pred_soft_top1 == true_exp).float().mean().item())

    topk = 3
    global_topk = torch.topk(global_prior, k=topk).indices
    soft_topk = torch.topk(comp_prior[comp_val], k=topk, dim=1).indices

    top3_global = float((true_exp.unsqueeze(1) == global_topk.unsqueeze(0)).any(dim=1).float().mean().item())
    top3_soft = float((soft_topk == true_exp.unsqueeze(1)).any(dim=1).float().mean().item())

    return {
        "nll_global": nll_global,
        "nll_soft": nll_soft,
        "top1_global": top1_global,
        "top1_soft": top1_soft,
        "top3_global": top3_global,
        "top3_soft": top3_soft,
    }

routing_eval = evaluate_routing_quality(
    mfa=mfa,
    X_val=X_val,
    expert_ids_val=expert_ids_val,
    comp_expert_counts=comp_expert_counts,
    expert_ids_train=expert_ids_train,
    device=device,
)

print("Held-out routing quality (lower NLL is better, higher Top-k is better):")
print(f"  Global prior NLL: {routing_eval['nll_global']:.4f}")
print(f"  Soft prior NLL:   {routing_eval['nll_soft']:.4f}")
print(f"  NLL improvement:  {routing_eval['nll_global'] - routing_eval['nll_soft']:.4f}")
print()
print(f"  Global Top-1: {100 * routing_eval['top1_global']:.2f}%")
print(f"  Soft Top-1:   {100 * routing_eval['top1_soft']:.2f}%")
print(f"  Top-1 gain:   {100 * (routing_eval['top1_soft'] - routing_eval['top1_global']):.2f} pp")
print()
print(f"  Global Top-3: {100 * routing_eval['top3_global']:.2f}%")
print(f"  Soft Top-3:   {100 * routing_eval['top3_soft']:.2f}%")
print(f"  Top-3 gain:   {100 * (routing_eval['top3_soft'] - routing_eval['top3_global']):.2f} pp")

labels = ["Global", "Soft"]
nll_vals = [routing_eval['nll_global'], routing_eval['nll_soft']]

top1_vals = [100 * routing_eval['top1_global'], 100 * routing_eval['top1_soft']]
top3_vals = [100 * routing_eval['top3_global'], 100 * routing_eval['top3_soft']]

fig, ax = plt.subplots(1, 2, figsize=(10, 4))
ax[0].bar(labels, nll_vals, color=["#4C78A8", "#F58518"])
ax[0].set_title("Routing Log Loss (val)")
ax[0].set_ylabel("NLL")

x = np.arange(len(labels))
width = 0.35
ax[1].bar(x - width / 2, top1_vals, width=width, label="Top-1", color="#54A24B")
ax[1].bar(x + width / 2, top3_vals, width=width, label="Top-3", color="#E45756")
ax[1].set_xticks(x)
ax[1].set_xticklabels(labels)
ax[1].set_ylabel("Accuracy (%)")
ax[1].set_title("Routing Match to Observed Expert (val)")
ax[1].legend()

plt.tight_layout()
plt.show()
# Out:
# Held-out routing quality (lower NLL is better, higher Top-k is better):
#   Global prior NLL: 1.9957
#   Soft prior NLL:   1.3960
#   NLL improvement:  0.5997
#
#   Global Top-1: 21.81%
#   Soft Top-1:   47.77%
#   Top-1 gain:   25.95 pp
#
#   Global Top-3: 56.38%
#   Soft Top-3:   81.04%
#   Top-3 gain:   24.66 pp

# %%
# Direct A/B: original router vs MFA-biased routing on the same held-out tokens
@torch.no_grad()
def compare_original_vs_mfa_routed(mfa, X_val, expert_ids_val, expert_probs_val, comp_expert_counts, device):
    eps = 1e-9

    # Build component-conditioned prior P(expert | component)
    comp_prior = (comp_expert_counts.float() + 1.0)
    comp_prior = comp_prior / comp_prior.sum(dim=1, keepdim=True).clamp_min(1e-8)

    # MFA component assignment for each validation token activation
    x_dev = X_val.to(device)
    alpha = mfa.responsibilities(x_dev)
    comp_val = alpha.argmax(dim=1).cpu()

    true_exp = expert_ids_val.cpu().long()
    p_orig = expert_probs_val.cpu().float().clamp_min(eps)

    # Probability assigned by MFA-biased prior to the original selected expert
    p_mfa_true = comp_prior[comp_val, true_exp].clamp_min(eps)

    # Predicted expert under MFA prior
    pred_mfa = torch.argmax(comp_prior[comp_val], dim=1)
    top1_mfa = float((pred_mfa == true_exp).float().mean().item())

    # Top-3 agreement
    top3_mfa = float(
        (torch.topk(comp_prior[comp_val], k=3, dim=1).indices == true_exp.unsqueeze(1))
        .any(dim=1)
        .float()
        .mean()
        .item()
    )

    # Confidence / NLL comparisons
    nll_orig = float((-torch.log(p_orig)).mean().item())
    nll_mfa = float((-torch.log(p_mfa_true)).mean().item())

    mean_conf_orig = float(p_orig.mean().item())
    mean_conf_mfa_true = float(p_mfa_true.mean().item())
    mean_conf_mfa_pred = float(torch.max(comp_prior[comp_val], dim=1).values.mean().item())

    return {
        "n_tokens": int(true_exp.numel()),
        "nll_original": nll_orig,
        "nll_mfa": nll_mfa,
        "top1_original": 1.0,
        "top1_mfa": top1_mfa,
        "top3_mfa": top3_mfa,
        "switch_rate": 1.0 - top1_mfa,
        "mean_conf_original": mean_conf_orig,
        "mean_conf_mfa_true": mean_conf_mfa_true,
        "mean_conf_mfa_pred": mean_conf_mfa_pred,
    }

ab_eval = compare_original_vs_mfa_routed(
    mfa=mfa,
    X_val=X_val,
    expert_ids_val=expert_ids_val,
    expert_probs_val=expert_probs_val,
    comp_expert_counts=comp_expert_counts,
    device=device,
)

print("Direct comparison on held-out tokens (original router vs MFA-biased routing):")
print(f"  Tokens evaluated: {ab_eval['n_tokens']}")
print()
print("Confidence / log-loss on original selected experts:")
print(f"  Original router NLL: {ab_eval['nll_original']:.4f}")
print(f"  MFA-biased NLL:      {ab_eval['nll_mfa']:.4f}")
print(f"  Delta (MFA - Orig):  {ab_eval['nll_mfa'] - ab_eval['nll_original']:.4f}")
print()
print("Agreement with original routing decisions:")
print(f"  Original Top-1 (by definition): {100 * ab_eval['top1_original']:.2f}%")
print(f"  MFA Top-1 agreement:            {100 * ab_eval['top1_mfa']:.2f}%")
print(f"  MFA Top-3 agreement:            {100 * ab_eval['top3_mfa']:.2f}%")
print(f"  Switch rate (expert changed):   {100 * ab_eval['switch_rate']:.2f}%")
print()
print("Average confidence:")
print(f"  Original mean top prob:         {ab_eval['mean_conf_original']:.4f}")
print(f"  MFA prob on original expert:    {ab_eval['mean_conf_mfa_true']:.4f}")
print(f"  MFA mean selected top prob:     {ab_eval['mean_conf_mfa_pred']:.4f}")

fig, ax = plt.subplots(1, 2, figsize=(10, 4))

# Left: NLL comparison
ax[0].bar(["Original", "MFA-biased"], [ab_eval["nll_original"], ab_eval["nll_mfa"]], color=["#4C78A8", "#F58518"])
ax[0].set_title("NLL on Original Selected Expert")
ax[0].set_ylabel("NLL (lower is better)")

# Right: agreement / switch
ax[1].bar(
    ["Top-1 agree", "Top-3 agree", "Switch rate"],
    [100 * ab_eval["top1_mfa"], 100 * ab_eval["top3_mfa"], 100 * ab_eval["switch_rate"]],
    color=["#54A24B", "#72B7B2", "#E45756"],
)
ax[1].set_title("MFA vs Original Routing")
ax[1].set_ylabel("Percent (%)")

plt.tight_layout()
plt.show()
# Out:
# Direct comparison on held-out tokens (original router vs MFA-biased routing):
#   Tokens evaluated: 1545
#
# Confidence / log-loss on original selected experts:
#   Original router NLL: 1.1160
#   MFA-biased NLL:      1.3960
#   Delta (MFA - Orig):  0.2800
#
# Agreement with original routing decisions:
#   Original Top-1 (by definition): 100.00%
#   MFA Top-1 agreement:            47.77%
#   MFA Top-3 agreement:            81.04%
#   Switch rate (expert changed):   52.23%
#
# Average confidence:
#   Original mean top prob:         0.3415
#   MFA prob on original expert:    0.3505
#   MFA mean selected top prob:     0.4842

# %%
# Output-level A/B comparison: original model vs MFA-biased routing during forward pass
@torch.no_grad()
def build_eval_prompts(dataset_obj, n_prompts=512, seed=0):
    batches = list(dataset_obj.get_batches(batch_size=1))
    rng = random.Random(seed)
    rng.shuffle(batches)

    prompts = []
    for b in batches:
        prompts.extend(b["prompt"])
        if len(prompts) >= n_prompts:
            break
    return prompts[:n_prompts]

@torch.no_grad()
def eval_prompt_nll(model, tokenizer, prompts, max_length=96, batch_size=4, desc="eval"):
    model.eval()
    total_nll = 0.0
    total_tokens = 0

    n_batches = (len(prompts) + batch_size - 1) // batch_size
    pbar = tqdm(range(0, len(prompts), batch_size), total=n_batches, desc=desc, leave=False)

    for i in pbar:
        chunk = prompts[i : i + batch_size]
        enc = tokenizer(
            chunk,
            return_tensors="pt",
            padding=True,
            truncation=True,
            max_length=max_length,
        )
        enc = {k: v.to(model.device) for k, v in enc.items()}

        labels = enc["input_ids"].clone()
        labels[enc["attention_mask"] == 0] = -100

        out = model(
            **enc,
            labels=labels,
            use_cache=False,
        )

        n_valid = int((labels != -100).sum().item())
        total_nll += float(out.loss.item()) * n_valid
        total_tokens += n_valid

        if total_tokens > 0:
            pbar.set_postfix(nll=f"{total_nll / total_tokens:.4f}")

    return total_nll / max(1, total_tokens)

@torch.no_grad()
def build_component_prior(comp_expert_counts, temperature=1.0):
    eps = 1e-9
    prior = (comp_expert_counts.float() + 1.0)
    prior = prior / prior.sum(dim=1, keepdim=True).clamp_min(1e-8)

    if temperature != 1.0:
        logits = torch.log(prior + eps) / float(temperature)
        prior = torch.softmax(logits, dim=1)

    return prior

@torch.no_grad()
def make_mfa_router_hook(mfa, comp_prior, mode="soft", lam=1.0, hard_margin=8.0):
    eps = 1e-9

    def hook_fn(module, module_input, module_output):
        # In JetMoE, the router is a linear layer that returns logits over experts.
        x = module_input[0]  # (N, D)
        alpha = mfa.responsibilities(x.to(mfa.mu.device, dtype=torch.float32))  # (N, K)
        comp = alpha.argmax(dim=1).cpu()  # (N,)

        if mode == "hard_top1":
            top_expert = torch.argmax(comp_prior[comp], dim=1).to(module_output.device)  # (N,)
            bias = torch.full_like(module_output, -hard_margin)
            bias.scatter_(1, top_expert.unsqueeze(1), hard_margin)
            return module_output + bias

        bias = torch.log(comp_prior[comp] + eps).to(module_output.device, dtype=module_output.dtype)  # (N, E)
        return module_output + float(lam) * bias

    return hook_fn

# Build priors
comp_prior_base = build_component_prior(comp_expert_counts, temperature=1.0)
comp_prior_sharp_t07 = build_component_prior(comp_expert_counts, temperature=0.7)
comp_prior_sharp_t05 = build_component_prior(comp_expert_counts, temperature=0.5)

# MFA-biased router linear layer hook point
layer_gate = model_hf.model.layers[router_layer].mlp.router.layer

# Safety cleanup: remove any stale hooks from interrupted runs
layer_gate._forward_hooks.clear()

# Bigger fixed prompt set for fair A/B output comparison
eval_prompts = build_eval_prompts(dataset_obj, n_prompts=512, seed=sample_seed)
print(f"Evaluating on {len(eval_prompts)} prompts")

# Baseline (original router)
nll_original = eval_prompt_nll(
    model=model_hf,
    tokenizer=tokenizer,
    prompts=eval_prompts,
    max_length=max_length,
    batch_size=4,
    desc="original",
)
print(f"Original router prompt NLL: {nll_original:.6f}")

# More decisive MFA routing variants
routing_configs = [
    {"label": "Soft λ=0.50", "mode": "soft", "lam": 0.5, "prior": comp_prior_base},
    {"label": "Soft λ=1.00", "mode": "soft", "lam": 1.0, "prior": comp_prior_base},
    {"label": "Soft λ=2.00", "mode": "soft", "lam": 2.0, "prior": comp_prior_base},
    {"label": "Soft λ=4.00", "mode": "soft", "lam": 4.0, "prior": comp_prior_base},
    {"label": "Sharp T=0.70 λ=2.0", "mode": "soft", "lam": 2.0, "prior": comp_prior_sharp_t07},
    {"label": "Sharp T=0.50 λ=2.0", "mode": "soft", "lam": 2.0, "prior": comp_prior_sharp_t05},
    {"label": "Hard Top-1", "mode": "hard_top1", "lam": 0.0, "prior": comp_prior_base},
]

mfa_output_eval = {}
for cfg in routing_configs:
    layer_gate._forward_hooks.clear()
    handle = layer_gate.register_forward_hook(
        make_mfa_router_hook(
            mfa,
            cfg["prior"],
            mode=cfg["mode"],
            lam=cfg["lam"],
            hard_margin=8.0,
        )
    )
    nll_mfa = eval_prompt_nll(
        model=model_hf,
        tokenizer=tokenizer,
        prompts=eval_prompts,
        max_length=max_length,
        batch_size=4,
        desc=cfg["label"],
    )
    handle.remove()

    mfa_output_eval[cfg["label"]] = nll_mfa
    print(f"{cfg['label']}: NLL={nll_mfa:.6f} | delta={nll_mfa - nll_original:+.6f}")

# Chart
labels = ["Original"] + [cfg["label"] for cfg in routing_configs]
vals = [nll_original] + [mfa_output_eval[cfg["label"]] for cfg in routing_configs]

plt.figure(figsize=(12, 4.5))
plt.bar(labels, vals, color=["#4C78A8"] + ["#F58518"] * len(routing_configs))
plt.ylabel("Prompt NLL (lower is better)")
plt.title("Output-level comparison with stronger MFA routing bias")
plt.xticks(rotation=30, ha="right")
plt.tight_layout()
plt.show()
# Out:
# Evaluating on 512 prompts
# Original router prompt NLL: 3.051740
# Soft λ=0.50: NLL=3.047624 | delta=-0.004116
# Soft λ=1.00: NLL=3.050561 | delta=-0.001179
# Soft λ=2.00: NLL=3.050066 | delta=-0.001674
# Soft λ=4.00: NLL=3.051688 | delta=-0.000051
# Sharp T=0.70 λ=2.0: NLL=3.051103 | delta=-0.000636
# Sharp T=0.50 λ=2.0:   6%|▋         | 8/128 [00:19<04:08,  2.07s/it, nll=3.0568]

# %%
def summarize_expert_semantic_correlation():
    """
    Summary of findings: Does expert routing correlate with semantic fields?
    """
    print("\n" + "="*70)
    print("SUMMARY: Expert Routing vs. Semantic Field Correlation")
    print("="*70)
    
    # Key finding 1: Expert specialization
    specialized_experts = [e for e, s in specialist_scores.items() if s > 3.0]
    print(f"\n1. SPECIALIZED EXPERTS (KL-div > 3.0): {len(specialized_experts)} out of {num_experts}")
    print(f"   These experts activate strongly in 1-2 specific semantic clusters.")
    
    generalist_experts = [e for e, s in specialist_scores.items() if s < 1.7]
    print(f"\n2. GENERALIST EXPERTS (KL-div < 1.7): {len(generalist_experts)} out of {num_experts}")
    print(f"   These experts activate uniformly across semantic clusters.")
    
    # Key finding 2: Expert consistency within components
    consistency_scores = []
    for comp in component_experts:
        if len(component_experts[comp]) > 0:
            expert_counter = Counter(component_experts[comp])
            consistency = max(expert_counter.values()) / len(component_experts[comp])
            consistency_scores.append((comp, consistency))
    
    consistency_scores.sort(key=lambda x: x[1], reverse=True)
    avg_consistency = sum(c for _, c in consistency_scores) / len(consistency_scores)
    
    print(f"\n3. EXPERT CONSISTENCY PER COMPONENT:")
    print(f"   Average: {avg_consistency:.3f} (0=uniform, 1=single expert)")
    print(f"   Top 5 consistent components:")
    for comp, cons in consistency_scores[:5]:
        print(f"     Component {comp}: {cons:.3f} consistency (expert does not vary much)")
    print(f"   Bottom 5 diverse components:")
    for comp, cons in consistency_scores[-5:]:
        print(f"     Component {comp}: {cons:.3f} consistency (experts vary widely)")
    
    # Key finding 3: Correlation strength
    print(f"\n4. CORRELATION INTERPRETATION:")
    print(f"   - High consistency (>0.5): Expert routing correlates with semantic content")
    print(f"   - Existence of specialist experts: Confirms semantic specialization in experts")
    print(f"   - Current avg consistency: {avg_consistency:.3f} -> Moderate correlation detected")
    
    print(f"\n5. OPPORTUNITY FOR ROUTING CONSTRAINTS:")
    print(f"   - Specialize routing: Force specialized experts to only activate in their strong components")
    print(f"   - Would reduce redundancy and potentially improve efficiency")
    print(f"   - Could use: component responsibility > threshold => select from specialist experts only")
    print("="*70 + "\n")

summarize_expert_semantic_correlation()
# Out:
# ======================================================================
# SUMMARY: Expert Routing vs. Semantic Field Correlation
# ======================================================================
#
# 1. SPECIALIZED EXPERTS (KL-div > 3.0): 7 out of 60
#    These experts activate strongly in 1-2 specific semantic clusters.
#
# 2. GENERALIST EXPERTS (KL-div < 1.7): 26 out of 60
#    These experts activate uniformly across semantic clusters.
#
# 3. EXPERT CONSISTENCY PER COMPONENT:
#    Average: 0.407 (0=uniform, 1=single expert)
#    Top 5 consistent components:
#      Component 74: 1.000 consistency (expert does not vary much)
#      Component 20: 1.000 consistency (expert does not vary much)
#      Component 1: 1.000 consistency (expert does not vary much)
#      Component 30: 1.000 consistency (expert does not vary much)
#      Component 22: 1.000 consistency (expert does not vary much)
#    Bottom 5 diverse components:
#      Component 53: 0.138 consistency (experts vary widely)
#      Component 47: 0.131 consistency (experts vary widely)
#      Component 32: 0.131 consistency (experts vary widely)
#      Component 48: 0.116 consistency (experts vary widely)
#      Component 39: 0.112 consistency (experts vary widely)
#
# 4. CORRELATION INTERPRETATION:
#    - High consistency (>0.5): Expert routing correlates with semantic content
#    - Existence of specialist experts: Confirms semantic specialization in experts
#    - Current avg consistency: 0.407 -> Moderate correlation detected
#
# 5. OPPORTUNITY FOR ROUTING CONSTRAINTS:
#    - Specialize routing: Force specialized experts to only activate in their strong components
#    - Would reduce redundancy and potentially improve efficiency
#    - Could use: component responsibility > threshold => select from specialist experts only
# ======================================================================
